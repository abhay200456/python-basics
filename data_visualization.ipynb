# %% [markdown]
# <a href="https://colab.research.google.com/github/abhay200456/python-basics/blob/main/data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=["a","b","c","d"]
y=[1,2,3,4]

# %%
#scatterpie
x=["support","nosupport","nocomment"]
y=[60,30,10]
plt.pie(y,labels=x)
# Out:
# ([<matplotlib.patches.Wedge at 0x7eda519dc220>,
# ...
#  [Text(-0.33991877217145816, 1.046162142464278, 'support'),
#   Text(2.0597886522865473e-07, -1.0999999999999808, 'nosupport'),
#   Text(1.0461622458970796, -0.339918453837944, 'nocomment')])

# %%
import numpy as np

x=np.random.randn(100)
y=np.random.randn(100)
plt.scatter(x,y)
